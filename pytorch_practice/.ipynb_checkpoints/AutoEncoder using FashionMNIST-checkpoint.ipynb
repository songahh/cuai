# %% [markdown]
# ## 1. Module Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %% [markdown]
# ## 2. 장치 확인

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(f'Using Pytorch version: {torch.__version__}, Device: {DEVICE}')
# Out:
# Using Pytorch version: 1.7.1, Device: cuda

# %% [markdown]
# ## 3. 데이터 load

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
# 데이터 다운로드
train_dataset = datasets.FashionMNIST(root = "../data/FashionMNIST",
                                      train = True,
                                      download = True,
                                      transform = transforms.ToTensor())
test_dataset = datasets.FashionMNIST(root = "../data/FashionMNIST",
                                     train = False,
                                     transform = transforms.ToTensor())

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)

# %% [markdown]
# ## 4. 데이터 확인하기

# %%
for (X_train, y_train) in train_loader:
    print(f'X_train size: {X_train.size()}, type: {X_train.type()}')
    print(f'y_train size: {y_train.size()}, type: {y_train.type()}')
    break
# Out:
# X_train size: torch.Size([32, 1, 28, 28]), type: torch.FloatTensor
# y_train size: torch.Size([32]), type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize = (10*pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class ' + str(y_train[i].item()))

# %% [markdown]
# ## 5. 모델 설계

# %%
class AE(nn.Module):
    
    def __init__(self):
        super(AE, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 32),)
        
        self.decoder = nn.Sequential(
            nn.Linear(32, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 28*28),)
        
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %% [markdown]
# ## 6. Initalization, Optimzation, Objective Function 설정

# %%
model = AE().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.MSELoss()

# %%
print(model)
# Out:
# AE(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=256, out_features=32, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=32, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=784, bias=True)
#   )
# )

# %% [markdown]
# ## 7. Train & Evaluate Function

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, _) in enumerate(train_loader):
        image = image.view(-1, 28*28).to(DEVICE)
        target = image.view(-1, 28*28).to(DEVICE)
        
        optimizer.zero_grad()
        encoded, decoded = model(image)
        loss = criterion(decoded, target)
        loss.backward()
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print(f'Train Epoch: {Epoch}, [{batch_idx*len(image)}/{len(train_loader.dataset)}({100.*batch_idx/len(train_loader):.0f}%)]\tTrain Loss: {loss.item():.6f}')

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    real_image = []
    gen_image = []
    
    with torch.no_grad():
        for image, _ in test_loader:
            image = image.view(-1, 28*28).to(DEVICE)
            target = image.view(-1, 28*28).to(DEVICE)
            encoded, decoded = model(image)
            
            test_loss += criterion(decoded, image).item()
            real_image.append(image.to('cpu'))
            gen_image.append(decoded.to('cpu'))
        
        test_loss /= len(test_loader.dataset)
        return test_loss, real_image, gen_image

# %% [markdown]
# ## 8. 학습 & 결과

# %%
for Epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, real_image, gen_image = evaluate(model, test_loader)
    print(f'\n[EPOCH:{Epoch}], \tTest Loss:{test_loss:.4f}')
    
    fig, ax = plt.subplots(2, 10, figsize=(10, 4))
    for i in range(10):
        img = np.reshape(real_image[0][i], (28, 28))
        ax[0][i].imshow(img, cmap = "gray_r")
        ax[0][i].set_xticks(())
        ax[0][i].set_yticks(())
        
    for i in range(10):
        img = np.reshape(gen_image[0][i], (28, 28))
        ax[1][i].imshow(img, cmap = "gray_r")
        ax[1][i].set_xticks(())
        ax[1][i].set_yticks(())
    
    plt.show()
# Out:
# Train Epoch: 1, [0/60000(0%)]	Train Loss: 0.188631
# Train Epoch: 1, [6400/60000(11%)]	Train Loss: 0.025139
# Train Epoch: 1, [12800/60000(21%)]	Train Loss: 0.022578
# Train Epoch: 1, [19200/60000(32%)]	Train Loss: 0.021977
# Train Epoch: 1, [25600/60000(43%)]	Train Loss: 0.020328
# Train Epoch: 1, [32000/60000(53%)]	Train Loss: 0.018479
# Train Epoch: 1, [38400/60000(64%)]	Train Loss: 0.017608
# Train Epoch: 1, [44800/60000(75%)]	Train Loss: 0.019115
# Train Epoch: 1, [51200/60000(85%)]	Train Loss: 0.016430
# Train Epoch: 1, [57600/60000(96%)]	Train Loss: 0.014708
#
# [EPOCH:1], 	Test Loss:0.0005
# Train Epoch: 2, [0/60000(0%)]	Train Loss: 0.011947
# Train Epoch: 2, [6400/60000(11%)]	Train Loss: 0.015968
# Train Epoch: 2, [12800/60000(21%)]	Train Loss: 0.015368
# Train Epoch: 2, [19200/60000(32%)]	Train Loss: 0.012323
# Train Epoch: 2, [25600/60000(43%)]	Train Loss: 0.013240
# Train Epoch: 2, [32000/60000(53%)]	Train Loss: 0.012420
# Train Epoch: 2, [38400/60000(64%)]	Train Loss: 0.011708
# Train Epoch: 2, [44800/60000(75%)]	Train Loss: 0.013218
# Train Epoch: 2, [51200/60000(85%)]	Train Loss: 0.013845
# Train Epoch: 2, [57600/60000(96%)]	Train Loss: 0.011248
#
# [EPOCH:2], 	Test Loss:0.0004
# Train Epoch: 3, [0/60000(0%)]	Train Loss: 0.011301
# Train Epoch: 3, [6400/60000(11%)]	Train Loss: 0.011454
# Train Epoch: 3, [12800/60000(21%)]	Train Loss: 0.015344
# Train Epoch: 3, [19200/60000(32%)]	Train Loss: 0.013699
# Train Epoch: 3, [25600/60000(43%)]	Train Loss: 0.015913
# Train Epoch: 3, [32000/60000(53%)]	Train Loss: 0.012206
# Train Epoch: 3, [38400/60000(64%)]	Train Loss: 0.011946
# Train Epoch: 3, [44800/60000(75%)]	Train Loss: 0.012307
# Train Epoch: 3, [51200/60000(85%)]	Train Loss: 0.011841
# Train Epoch: 3, [57600/60000(96%)]	Train Loss: 0.013675
#
# [EPOCH:3], 	Test Loss:0.0004
# Train Epoch: 4, [0/60000(0%)]	Train Loss: 0.013710
# Train Epoch: 4, [6400/60000(11%)]	Train Loss: 0.011074
# Train Epoch: 4, [12800/60000(21%)]	Train Loss: 0.012543
# Train Epoch: 4, [19200/60000(32%)]	Train Loss: 0.013467
# Train Epoch: 4, [25600/60000(43%)]	Train Loss: 0.009706
# Train Epoch: 4, [32000/60000(53%)]	Train Loss: 0.008653
# Train Epoch: 4, [38400/60000(64%)]	Train Loss: 0.012103
# Train Epoch: 4, [44800/60000(75%)]	Train Loss: 0.010571
# Train Epoch: 4, [51200/60000(85%)]	Train Loss: 0.013049
# Train Epoch: 4, [57600/60000(96%)]	Train Loss: 0.012925
#
# [EPOCH:4], 	Test Loss:0.0004
# Train Epoch: 5, [0/60000(0%)]	Train Loss: 0.010521
# Train Epoch: 5, [6400/60000(11%)]	Train Loss: 0.010100
# Train Epoch: 5, [12800/60000(21%)]	Train Loss: 0.010875
# Train Epoch: 5, [19200/60000(32%)]	Train Loss: 0.009032
# Train Epoch: 5, [25600/60000(43%)]	Train Loss: 0.011607
# Train Epoch: 5, [32000/60000(53%)]	Train Loss: 0.010178
# Train Epoch: 5, [38400/60000(64%)]	Train Loss: 0.012951
# Train Epoch: 5, [44800/60000(75%)]	Train Loss: 0.009424
# Train Epoch: 5, [51200/60000(85%)]	Train Loss: 0.009347
# Train Epoch: 5, [57600/60000(96%)]	Train Loss: 0.011136
#
# [EPOCH:5], 	Test Loss:0.0003
# Train Epoch: 6, [0/60000(0%)]	Train Loss: 0.011027
# Train Epoch: 6, [6400/60000(11%)]	Train Loss: 0.009291
# Train Epoch: 6, [12800/60000(21%)]	Train Loss: 0.010140
# Train Epoch: 6, [19200/60000(32%)]	Train Loss: 0.011646
# Train Epoch: 6, [25600/60000(43%)]	Train Loss: 0.009948
# Train Epoch: 6, [32000/60000(53%)]	Train Loss: 0.011139
# Train Epoch: 6, [38400/60000(64%)]	Train Loss: 0.012660
# Train Epoch: 6, [44800/60000(75%)]	Train Loss: 0.012852
# Train Epoch: 6, [51200/60000(85%)]	Train Loss: 0.008903
# Train Epoch: 6, [57600/60000(96%)]	Train Loss: 0.014909
#
# [EPOCH:6], 	Test Loss:0.0003
# Train Epoch: 7, [0/60000(0%)]	Train Loss: 0.010752
# Train Epoch: 7, [6400/60000(11%)]	Train Loss: 0.009374
# Train Epoch: 7, [12800/60000(21%)]	Train Loss: 0.010381
# Train Epoch: 7, [19200/60000(32%)]	Train Loss: 0.013240
# Train Epoch: 7, [25600/60000(43%)]	Train Loss: 0.012450
# Train Epoch: 7, [32000/60000(53%)]	Train Loss: 0.008807
# Train Epoch: 7, [38400/60000(64%)]	Train Loss: 0.010288
# Train Epoch: 7, [44800/60000(75%)]	Train Loss: 0.009972
# Train Epoch: 7, [51200/60000(85%)]	Train Loss: 0.010650
# Train Epoch: 7, [57600/60000(96%)]	Train Loss: 0.008579
#
# [EPOCH:7], 	Test Loss:0.0003
# Train Epoch: 8, [0/60000(0%)]	Train Loss: 0.010059
# Train Epoch: 8, [6400/60000(11%)]	Train Loss: 0.012547
# Train Epoch: 8, [12800/60000(21%)]	Train Loss: 0.009628
# Train Epoch: 8, [19200/60000(32%)]	Train Loss: 0.011217
# Train Epoch: 8, [25600/60000(43%)]	Train Loss: 0.009866
# Train Epoch: 8, [32000/60000(53%)]	Train Loss: 0.011125
# Train Epoch: 8, [38400/60000(64%)]	Train Loss: 0.010931
# Train Epoch: 8, [44800/60000(75%)]	Train Loss: 0.008158
# Train Epoch: 8, [51200/60000(85%)]	Train Loss: 0.010795
# Train Epoch: 8, [57600/60000(96%)]	Train Loss: 0.008432
#
# [EPOCH:8], 	Test Loss:0.0003
# Train Epoch: 9, [0/60000(0%)]	Train Loss: 0.009094
# Train Epoch: 9, [6400/60000(11%)]	Train Loss: 0.009014
# Train Epoch: 9, [12800/60000(21%)]	Train Loss: 0.009994
# Train Epoch: 9, [19200/60000(32%)]	Train Loss: 0.008799
# Train Epoch: 9, [25600/60000(43%)]	Train Loss: 0.007372
# Train Epoch: 9, [32000/60000(53%)]	Train Loss: 0.008894
# Train Epoch: 9, [38400/60000(64%)]	Train Loss: 0.009280
# Train Epoch: 9, [44800/60000(75%)]	Train Loss: 0.009587
# Train Epoch: 9, [51200/60000(85%)]	Train Loss: 0.010875
# Train Epoch: 9, [57600/60000(96%)]	Train Loss: 0.011013
#
# [EPOCH:9], 	Test Loss:0.0003
# Train Epoch: 10, [0/60000(0%)]	Train Loss: 0.009332
# Train Epoch: 10, [6400/60000(11%)]	Train Loss: 0.009287
# Train Epoch: 10, [12800/60000(21%)]	Train Loss: 0.009100
# Train Epoch: 10, [19200/60000(32%)]	Train Loss: 0.010948
# Train Epoch: 10, [25600/60000(43%)]	Train Loss: 0.008883
# Train Epoch: 10, [32000/60000(53%)]	Train Loss: 0.009785
# Train Epoch: 10, [38400/60000(64%)]	Train Loss: 0.009985
# Train Epoch: 10, [44800/60000(75%)]	Train Loss: 0.010206
# Train Epoch: 10, [51200/60000(85%)]	Train Loss: 0.011081
# Train Epoch: 10, [57600/60000(96%)]	Train Loss: 0.008361
#
# [EPOCH:10], 	Test Loss:0.0003
